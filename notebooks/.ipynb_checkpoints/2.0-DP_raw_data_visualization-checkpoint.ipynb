# %%
cd data/raw
# Out:
# /Users/danylopoliakov/Documents/GitHub/Tanzania_waterpomps/data/raw

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
target = pd.read_csv('target.csv')

# %%
import pygal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-6112bc28678f> in <module>
# ----> 1 import pygal
#
# ModuleNotFoundError: No module named 'pygal'

# %%
line_chart = pygal.Bar()
line_chart.title = 'Browser usage evolution (in %)'
line_chart.x_labels = map(str, range(2002, 2013))
line_chart.add('Firefox', [None, None, 0, 16.6,   25,   31, 36.4, 45.5, 46.3, 42.8, 37.1])
line_chart.add('Chrome',  [None, None, None, None, None, None,    0,  3.9, 10.8, 23.8, 35.3])
line_chart.add('IE',      [85.8, 84.6, 84.7, 74.5,   66, 58.6, 54.7, 44.8, 36.2, 26.6, 20.1])
line_chart.add('Others',  [14.2, 15.4, 15.3,  8.9,    9, 10.4,  8.9,  5.8,  6.7,  6.8,  7.5])
line_chart.render()
# Out:
# b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-b4122c3f-1100-45ad-b4cd-7267a49804eb" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2019-07-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb{background-color:rgba(249,249,249,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb path,#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb line,#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb rect,#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .graph{fill:rgba(0,0,0,.87)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb text.no_data{fill:rgba(0,0,0,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .title{fill:rgba(0,0,0,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .legends .legend text{fill:rgba(0,0,0,.87)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .axis .line{stroke:rgba(0,0,0,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .axis text.major{fill:rgba(0,0,0,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .axis.y .guides:hover .guide.line,#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .line-graph .axis.x .guides:hover .guide.line,#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .stackedline-graph .axis.x .guides:hover .guide.line,#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .ci{stroke:rgba(0,0,0,.87)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .reactive.active,#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .ci .reactive.active{stroke-width:1.5}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .series text{fill:rgba(0,0,0,1)}#chart-b4122c3f-1100-45ad-b4cd-7267a49804eb .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-m ...
